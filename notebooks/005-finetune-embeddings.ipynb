# %% [markdown]
# # Finetune embeddings

# %% [markdown]
# # Set up

# %%
import os
from loguru import logger
from tqdm.notebook import tqdm

# %%
import pandas as pd

# %%
from pydantic import BaseModel

class Config(BaseModel):
    testing: bool = False

    data_fp: str = "../data/yelp_dataset/sample/sample_100_biz/denom_review.parquet"
    storage_context_persist_dp: str = "./data/finetune_embedding/storage_context"
    gen_qa_embedding_pairs_dp: str = "./data/finetune_embedding/gen_qa_embedding_pairs"
    ft_model_dp: str = "./data/finetune_embedding/finetuned_model"
    eval_dp: str = "./data/finetune_embedding/eval"

    num_questions_per_chunk: int = 2

cfg = Config()

# %%
data = pd.read_parquet(cfg.data_fp)
data = data.assign(
    biz_categories=lambda df: df['biz_categories'].str.split(', '),
    date=lambda df: df['date'].dt.strftime('%Y-%m-%dT%H:%M:%S')
)
logger.info(f"[COLLECT] {len(data)=}")
data.iloc[0]
# Out:
# 2024-08-10 08:17:37.950 | INFO     | __main__:<module>:6 - [COLLECT] len(data)=5240
# review_id                                      L0jv8c2FbpWSlfNC6bbUEA
# user_id                                        bFPdtzu11Oi0f92EAcjqmg
# business_id                                    IDtLPgUrqorrpqSLdfMhZQ
# review_stars                                                        5
# useful                                                              0
# funny                                                               0
# cool                                                                0
# text                What a great addition to the Funk Zone!  Grab ...
# date                                              2016-10-13T22:50:47
# biz_name                                         Helena Avenue Bakery
# biz_address                                     131 Anacapa St, Ste C
# biz_city                                                Santa Barbara
# biz_state                                                          CA
# biz_postal_code                                                 93101
# biz_latitude                                                34.414445
# biz_longitude                                             -119.690672
# biz_stars                                                         4.0
# biz_review_count                                                  389
# biz_is_open                                                         1
# biz_attributes      {'AcceptsInsurance': None, 'Alcohol': 'u'none'...
# biz_categories      [Food, Restaurants, Salad, Coffee & Tea, Break...
# biz_hours           {'Friday': '8:0-14:0', 'Monday': '0:0-0:0', 'S...
# Name: 0, dtype: object

# %%
data.shape
# Out:
# (5240, 22)

# %%
business_ids = data['business_id'].unique()
len(business_ids)
# Out:
# 100

# %% [markdown]
# # Split train test

# %%
import numpy as np

# %%
TRAIN_RATIO = 0.7

np.random.seed(41)
train_business_ids = np.random.choice(business_ids, int(TRAIN_RATIO * len(business_ids)), replace=False)
val_business_ids = [id_ for id_ in business_ids if id_ not in train_business_ids]
logger.info(f"{len(train_business_ids)=}, {len(val_business_ids)=}")
# Out:
# 2024-08-10 08:17:37.989 | INFO     | __main__:<module>:6 - len(train_business_ids)=70, len(val_business_ids)=30

# %%
train_df = data.loc[lambda df: df['business_id'].isin(train_business_ids)]
val_df = data.loc[lambda df: df['business_id'].isin(val_business_ids)]

# %% [markdown]
# # Convert to Documents

# %%
from llama_index.core import Document

def prep_documents(input_data: pd.DataFrame):
    documents = []
    embedding_visible_metadata = ["review_stars", "biz_name", "biz_address", "biz_city", "biz_state", "biz_categories"]
    excluded_embed_metadata_keys = [k for k in input_data.columns if k not in embedding_visible_metadata]
    
    for i, row in tqdm(input_data.iterrows(), total=len(input_data)):
        record = row.to_dict()
        text = record['text']
        metadata = {k: v for k, v in record.items() if k not in ('text')}
        
        doc = Document(
            text=text,
            metadata=metadata,
            excluded_embed_metadata_keys=excluded_embed_metadata_keys,
            excluded_llm_metadata_keys=excluded_embed_metadata_keys
        )
        documents.append(doc)
    
    return documents

# %%
train_docs = prep_documents(train_df)
val_docs = prep_documents(val_df)
# Out:
#   0%|          | 0/3176 [00:00<?, ?it/s]
#   0%|          | 0/2064 [00:00<?, ?it/s]

# %%
train_docs[0]
# Out:
# Document(id_='566d233c-c727-4485-9b0f-e8f53452b013', embedding=None, metadata={'review_id': 'L0jv8c2FbpWSlfNC6bbUEA', 'user_id': 'bFPdtzu11Oi0f92EAcjqmg', 'business_id': 'IDtLPgUrqorrpqSLdfMhZQ', 'review_stars': 5, 'useful': 0, 'funny': 0, 'cool': 0, 'date': '2016-10-13T22:50:47', 'biz_name': 'Helena Avenue Bakery', 'biz_address': '131 Anacapa St, Ste C', 'biz_city': 'Santa Barbara', 'biz_state': 'CA', 'biz_postal_code': '93101', 'biz_latitude': 34.4144445, 'biz_longitude': -119.6906718, 'biz_stars': 4.0, 'biz_review_count': 389, 'biz_is_open': 1, 'biz_attributes': {'AcceptsInsurance': None, 'Alcohol': "u'none'", 'Ambience': "{'touristy': False, 'hipster': True, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': True, 'upscale': False, 'classy': False, 'casual': True}", 'BYOB': None, 'BestNights': None, 'BikeParking': 'True', 'BusinessAcceptsBitcoin': None, 'BusinessAcceptsCreditCards': 'True', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'ByAppointmentOnly': None, 'Caters': 'True', 'CoatCheck': None, 'Corkage': None, 'DogsAllowed': 'True', 'DriveThru': None, 'GoodForDancing': None, 'GoodForKids': 'True', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}", 'HappyHour': 'False', 'HasTV': 'False', 'Music': None, 'NoiseLevel': "u'average'", 'OutdoorSeating': 'True', 'RestaurantsAttire': "'casual'", 'RestaurantsDelivery': 'None', 'RestaurantsGoodForGroups': 'True', 'RestaurantsPriceRange2': '2', 'RestaurantsReservations': 'False', 'RestaurantsTableService': 'False', 'RestaurantsTakeOut': 'True', 'Smoking': None, 'WheelchairAccessible': 'True', 'WiFi': "u'no'"}, 'biz_categories': ['Food', 'Restaurants', 'Salad', 'Coffee & Tea', 'Breakfast & Brunch', 'Sandwiches', 'Bakeries'], 'biz_hours': {'Friday': '8:0-14:0', 'Monday': '0:0-0:0', 'Saturday': '8:0-14:0', 'Sunday': '8:0-14:0', 'Thursday': '8:0-14:0', 'Tuesday': '8:0-14:0', 'Wednesday': '8:0-14:0'}}, excluded_embed_metadata_keys=['review_id', 'user_id', 'business_id', 'useful', 'funny', 'cool', 'text', 'date', 'biz_postal_code', 'biz_latitude', 'biz_longitude', 'biz_stars', 'biz_review_count', 'biz_is_open', 'biz_attributes', 'biz_hours'], excluded_llm_metadata_keys=['review_id', 'user_id', 'business_id', 'useful', 'funny', 'cool', 'text', 'date', 'biz_postal_code', 'biz_latitude', 'biz_longitude', 'biz_stars', 'biz_review_count', 'biz_is_open', 'biz_attributes', 'biz_hours'], relationships={}, text='What a great addition to the Funk Zone!  Grab a bite, grab some tastings, life is good. Right next door to the Santa Barbara Wine Collective, in fact it actually shares the same tables.  We had a fabulous savory croissant.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %% [markdown]
# # Chunking

# %%
import time
import pickle
from multiprocessing import set_start_method
from llama_index.core.storage.docstore import SimpleDocumentStore
from llama_index.core.node_parser import SemanticSplitterNodeParser

from llama_index.core.extractors import TitleExtractor
from llama_index.core.ingestion import IngestionPipeline, IngestionCache

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embedding_model_name = "Snowflake/snowflake-arctic-embed-m-v1.5"
embed_model = HuggingFaceEmbedding(model_name=embedding_model_name)
# Out:
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# Some weights of BertModel were not initialized from the model checkpoint at Snowflake/snowflake-arctic-embed-m-v1.5 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
chunker = SemanticSplitterNodeParser
chunker_cfg = {
    "buffer_size": 1,
    "breakpoint_percentile_threshold": 95,
    "embed_model": embed_model
}

# %%
RECREATE_INDEX = False

# %%
from llama_index.core import StorageContext

if RECREATE_INDEX or not os.path.exists(f"{cfg.storage_context_persist_dp}/train"):
    t0 = time.perf_counter()
    # create the pipeline with transformations
    pipeline = IngestionPipeline(
        transformations=[
            chunker(**chunker_cfg),
            embed_model,
        ]
    )
    
    num_workers = None
    # TODO: I can get the preprocessing completed much quicker if I push the initial steps through a multiprocessing loop and then separately create the embeddings using the built-in batching already provided in the SentenceTransformer encode method.
    # Ref: https://github.com/run-llama/llama_index/issues/10104#issuecomment-1899401584
    # Currently setting num_workers leads to code simple hang
    # Ref: https://github.com/run-llama/llama_index/issues/10104
    # num_workers = os.cpu_count() - 1
    # os.environ['TOKENIZERS_PARALLELISM'] = 'true'
    # set_start_method("spawn", force=True)  # it hangs without this line
    logger.info(f"Running Ingestion Pipeline with {num_workers=}...")
    train_nodes = await pipeline.arun(documents=train_docs, num_workers=num_workers, show_progress=True)
    val_nodes = await pipeline.arun(documents=val_docs, num_workers=num_workers, show_progress=True)
    t1 = time.perf_counter()
    logger.info(f"Building nodes for train and val took {t1 - t0:,.0f}s")
    
    t0 = time.perf_counter()
    # Define Docstore as an abstraction on top of nodes to easily manage (e.g. get node by id)
    train_docstore = SimpleDocumentStore()
    await train_docstore.async_add_documents(train_nodes)
    train_storage_context = StorageContext.from_defaults(
        docstore=train_docstore
    )
    train_storage_context.persist(f"{cfg.storage_context_persist_dp}/train")
    
    val_docstore = SimpleDocumentStore()
    await val_docstore.async_add_documents(val_nodes)
    val_storage_context = StorageContext.from_defaults(
        docstore=val_docstore
    )
    val_storage_context.persist(f"{cfg.storage_context_persist_dp}/val")
    
    t1 = time.perf_counter()
    logger.info(f"Persisting storage_context for train and val took {t1 - t0:,.0f}s")
else:
    logger.info(f"Loading Storage Context from {cfg.storage_context_persist_dp}...")
    train_docstore = SimpleDocumentStore.from_persist_dir(persist_dir=f"{cfg.storage_context_persist_dp}/train")
    train_storage_context = StorageContext.from_defaults(
        docstore=train_docstore
    )
    train_nodes = list(train_docstore.docs.values())

    val_docstore = SimpleDocumentStore.from_persist_dir(persist_dir=f"{cfg.storage_context_persist_dp}/val")
    val_storage_context = StorageContext.from_defaults(
        docstore=val_docstore
    )
    val_nodes = list(val_docstore.docs.values())
# Out:
# 2024-08-10 08:17:46.553 | INFO     | __main__:<module>:46 - Loading Storage Context from ./data/finetune_embedding/storage_context...

# %% [markdown]
# # Generate synthetic queries

# %%
REGEN_DATASET = False

# %%
from llama_index.finetuning import generate_qa_embedding_pairs
from llama_index.core.evaluation import generate_question_context_pairs
from llama_index.core.evaluation import EmbeddingQAFinetuneDataset
from llama_index.core.schema import MetadataMode

# %%
if cfg.testing:
    gen_train_nodes = train_nodes[:10]
    gen_val_nodes = val_nodes[:10]
else:
    gen_train_nodes = train_nodes
    gen_val_nodes = val_nodes

# %%
logger.info(f"{len(gen_train_nodes)=}, {len(gen_val_nodes)=}")
# Out:
# 2024-08-10 08:17:54.381 | INFO     | __main__:<module>:1 - len(gen_train_nodes)=6218, len(gen_val_nodes)=4001

# %%
from llama_index.llms.openai import OpenAI

llm_model_name = 'gpt-4o-mini'
llm = OpenAI(model=llm_model_name)

# %%
print(gen_train_nodes[0].get_content(metadata_mode=MetadataMode.LLM))
# Out:
# review_stars: 5
# biz_name: Helena Avenue Bakery
# biz_address: 131 Anacapa St, Ste C
# biz_city: Santa Barbara
# biz_state: CA
# biz_categories: ['Food', 'Restaurants', 'Salad', 'Coffee & Tea', 'Breakfast & Brunch', 'Sandwiches', 'Bakeries']
#
# What a great addition to the Funk Zone!  Grab a bite, grab some tastings, life is good.

# %%
train_output_path = f"{cfg.gen_qa_embedding_pairs_dp}/train/qa_finetuned_dataset.json"
val_output_path = f"{cfg.gen_qa_embedding_pairs_dp}/val/qa_finetuned_dataset.json"

if REGEN_DATASET:
    # Generate 10K pairs of questions and answers costs about 0.7 USD using GPT-4o-mini
    gen_query_prompt_tmpl = """
    You are a helpful assistant.
    
    Your task is to generate {num_questions_per_chunk} questions based on only the given context, not prior information.
    The questions are aim to find businesses/locations to go to, for example: restaurants, shopping mall, parking lots, ...
    
    <EXAMPLE>
    Input context: Biz_name: Clara's Kitchen. What a great addition to the Funk Zone!  Grab a bite, grab some tastings, life is good. Right next door to the Santa Barbara Wine Collective, in fact it actually shares the same tables.  We had a fabulous savory croissant.
    Output questions: What are some recommended restaurants in Funk Zone?
    
    Some example of good generated questions:
    - What are some reliable shipping or delivery services in Affton?
    - What are some clothing stores with good quality customer service or support?
    
    </EXAMPLE>
    
    IMPORTANT RULES:
    - The generated questions must be specific about the categories of businesses it's looking for. A good generated question would have its typical answer being: Here are some options for you: Place A because..., Place B because...
    - Restrict the generated question to the context information provided
    - Pay attention to the sentiment of the context review. If the review is bad then never return a question that ask for a good experience.
    - Do not mention anything about the context in the generated queries
    - The generated questions must be complete on its own. Do not assume the person receiving the question know anything about the person asking the question. for example never use "in my area" or "near me".
    
    Input context is below.
    
    ---------------------
    {context_str}
    ---------------------
    
    Output questions:
    """
    t0 = time.perf_counter()
    
    train_dataset = generate_question_context_pairs(
        gen_train_nodes,
        llm=llm,
        num_questions_per_chunk=1,
        qa_generate_prompt_tmpl=gen_query_prompt_tmpl,
    )
    
    t1 = time.perf_counter()
    logger.info(f"Generate {len(gen_train_nodes) * cfg.num_questions_per_chunk} questions for train set took {t1 - t0:,.0f}s")
    
    val_dataset = generate_question_context_pairs(
        gen_val_nodes,
        llm=llm,
        num_questions_per_chunk=1,
        qa_generate_prompt_tmpl=gen_query_prompt_tmpl,
    )
    
    t2 = time.perf_counter()
    logger.info(f"Generate {len(gen_val_nodes) * cfg.num_questions_per_chunk} questions for val set took {t1 - t0:,.0f}s")

    os.makedirs(os.path.dirname(train_output_path), exist_ok=True)
    logger.info(f"Persisting train dataset to {train_output_path}...")
    train_dataset.save_json(train_output_path)
    
    os.makedirs(os.path.dirname(val_output_path), exist_ok=True)
    logger.info(f"Persisting val dataset to {val_output_path}...")
    val_dataset.save_json(val_output_path)
else:
    logger.info(f"Loading train and val dataset from disk...")
    train_dataset = EmbeddingQAFinetuneDataset.from_json(train_output_path)
    val_dataset = EmbeddingQAFinetuneDataset.from_json(val_output_path)
# Out:
# 2024-08-10 08:17:54.415 | INFO     | __main__:<module>:66 - Loading train and val dataset from disk...

# %%
logger.info(f"len train_dataset: {len(list(train_dataset.relevant_docs.values()))}, len val_dataset: {len(list(val_dataset.relevant_docs.values()))}")
# Out:
# 2024-08-10 08:17:54.478 | INFO     | __main__:<module>:1 - len train_dataset: 6218, len val_dataset: 4001

# %%
sanity_node = list(val_dataset.relevant_docs.values())[0][0]
sanity_question = list(val_dataset.queries.values())[0]

# %%
print(f"""
Generated Question:
{sanity_question}

From Context:
{val_docstore.get_node(sanity_node).get_content(metadata_mode=MetadataMode.LLM)}
"""
)
# Out:
# Generated Question:
# What are some restaurants known for large portion sizes?
#
# From Context:
# review_stars: 5
# biz_name: Mike's Ice Cream
# biz_address: 129 2nd Ave N
# biz_city: Nashville
# biz_state: TN
# biz_categories: ['Ice Cream & Frozen Yogurt', 'Coffee & Tea', 'Restaurants', 'Sandwiches', 'Food']
#
# Super tasty and enormous portions.

# %% [markdown]
# # Run Embedding Finetuning

# %%
from llama_index.finetuning import SentenceTransformersFinetuneEngine

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Training Duration)</code>:</b>
# The below fine-tuning takes about 2 hours to complete.
# </p>

# %%
BATCH_SIZE = 4 # For 4 GB vRAM device can not take more. Looks like 1 unit increase in batch size takes up 500 MB vRAM

finetune_engine = SentenceTransformersFinetuneEngine(
    train_dataset,
    model_id=embedding_model_name,
    model_output_path=cfg.ft_model_dp,
    val_dataset=val_dataset,
    batch_size=BATCH_SIZE
)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: Snowflake/snowflake-arctic-embed-m-v1.5
# Load pretrained SentenceTransformer: Snowflake/snowflake-arctic-embed-m-v1.5
# WARNING:sentence_transformers.SentenceTransformer:You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# Some weights of BertModel were not initialized from the model checkpoint at Snowflake/snowflake-arctic-embed-m-v1.5 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:1 prompts are loaded, with the keys: ['query']
# 1 prompts are loaded, with the keys: ['query']

# %%
# %%time
finetune_engine.finetune()
# Out:
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1555 [00:00<?, ?it/s]
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 50 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 50 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 14.90%
# Accuracy@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 22.32%
# Accuracy@3: 22.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 26.47%
# Accuracy@5: 26.47%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 32.59%
# Accuracy@10: 32.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 14.90%
# Precision@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 7.44%
# Precision@3: 7.44%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 5.29%
# Precision@5: 5.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 3.26%
# Precision@10: 3.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 14.90%
# Recall@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 22.32%
# Recall@3: 22.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 26.47%
# Recall@5: 26.47%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 32.59%
# Recall@10: 32.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.1988
# MRR@10: 0.1988
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.2289
# NDCG@10: 0.2289
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.2079
# MAP@100: 0.2079
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 14.90%
# Accuracy@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 22.32%
# Accuracy@3: 22.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 26.47%
# Accuracy@5: 26.47%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 32.59%
# Accuracy@10: 32.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 14.90%
# Precision@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 7.44%
# Precision@3: 7.44%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 5.29%
# Precision@5: 5.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 3.26%
# Precision@10: 3.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 14.90%
# Recall@1: 14.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 22.32%
# Recall@3: 22.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 26.47%
# Recall@5: 26.47%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 32.59%
# Recall@10: 32.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.1988
# MRR@10: 0.1988
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.2289
# NDCG@10: 0.2289
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.2079
# MAP@100: 0.2079
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 100 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 100 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 19.82%
# Accuracy@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 29.72%
# Accuracy@3: 29.72%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 35.09%
# Accuracy@5: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 41.99%
# Accuracy@10: 41.99%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 19.82%
# Precision@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 9.91%
# Precision@3: 9.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 7.02%
# Precision@5: 7.02%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 4.20%
# Precision@10: 4.20%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 19.82%
# Recall@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 29.72%
# Recall@3: 29.72%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 35.09%
# Recall@5: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 41.99%
# Recall@10: 41.99%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.2629
# MRR@10: 0.2629
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3001
# NDCG@10: 0.3001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.2735
# MAP@100: 0.2735
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 19.82%
# Accuracy@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 29.72%
# Accuracy@3: 29.72%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 35.09%
# Accuracy@5: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 41.99%
# Accuracy@10: 41.99%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 19.82%
# Precision@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 9.91%
# Precision@3: 9.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 7.02%
# Precision@5: 7.02%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 4.20%
# Precision@10: 4.20%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 19.82%
# Recall@1: 19.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 29.72%
# Recall@3: 29.72%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 35.09%
# Recall@5: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 41.99%
# Recall@10: 41.99%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.2629
# MRR@10: 0.2629
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3001
# NDCG@10: 0.3001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.2735
# MAP@100: 0.2735
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 150 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 150 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 24.37%
# Accuracy@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 35.64%
# Accuracy@3: 35.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 41.64%
# Accuracy@5: 41.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 49.26%
# Accuracy@10: 49.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 24.37%
# Precision@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 11.88%
# Precision@3: 11.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 8.33%
# Precision@5: 8.33%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 4.93%
# Precision@10: 4.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 24.37%
# Recall@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 35.64%
# Recall@3: 35.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 41.64%
# Recall@5: 41.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 49.26%
# Recall@10: 49.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3167
# MRR@10: 0.3167
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3585
# NDCG@10: 0.3585
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3279
# MAP@100: 0.3279
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 24.37%
# Accuracy@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 35.64%
# Accuracy@3: 35.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 41.64%
# Accuracy@5: 41.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 49.26%
# Accuracy@10: 49.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 24.37%
# Precision@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 11.88%
# Precision@3: 11.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 8.33%
# Precision@5: 8.33%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 4.93%
# Precision@10: 4.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 24.37%
# Recall@1: 24.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 35.64%
# Recall@3: 35.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 41.64%
# Recall@5: 41.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 49.26%
# Recall@10: 49.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3167
# MRR@10: 0.3167
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3585
# NDCG@10: 0.3585
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3279
# MAP@100: 0.3279
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 200 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 200 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 26.69%
# Accuracy@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 39.89%
# Accuracy@3: 39.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 45.76%
# Accuracy@5: 45.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 54.11%
# Accuracy@10: 54.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 26.69%
# Precision@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 13.30%
# Precision@3: 13.30%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 9.15%
# Precision@5: 9.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.41%
# Precision@10: 5.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 26.69%
# Recall@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 39.89%
# Recall@3: 39.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 45.76%
# Recall@5: 45.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 54.11%
# Recall@10: 54.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3486
# MRR@10: 0.3486
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3944
# NDCG@10: 0.3944
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3596
# MAP@100: 0.3596
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 26.69%
# Accuracy@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 39.89%
# Accuracy@3: 39.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 45.76%
# Accuracy@5: 45.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 54.11%
# Accuracy@10: 54.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 26.69%
# Precision@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 13.30%
# Precision@3: 13.30%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 9.15%
# Precision@5: 9.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.41%
# Precision@10: 5.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 26.69%
# Recall@1: 26.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 39.89%
# Recall@3: 39.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 45.76%
# Recall@5: 45.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 54.11%
# Recall@10: 54.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3486
# MRR@10: 0.3486
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.3944
# NDCG@10: 0.3944
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3596
# MAP@100: 0.3596
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 250 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 250 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 29.19%
# Accuracy@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 42.21%
# Accuracy@3: 42.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 48.51%
# Accuracy@5: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 56.39%
# Accuracy@10: 56.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 29.19%
# Precision@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 14.07%
# Precision@3: 14.07%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 9.70%
# Precision@5: 9.70%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.64%
# Precision@10: 5.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 29.19%
# Recall@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 42.21%
# Recall@3: 42.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 48.51%
# Recall@5: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 56.39%
# Recall@10: 56.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3736
# MRR@10: 0.3736
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4189
# NDCG@10: 0.4189
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3850
# MAP@100: 0.3850
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 29.19%
# Accuracy@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 42.21%
# Accuracy@3: 42.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 48.51%
# Accuracy@5: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 56.41%
# Accuracy@10: 56.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 29.19%
# Precision@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 14.07%
# Precision@3: 14.07%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 9.70%
# Precision@5: 9.70%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.64%
# Precision@10: 5.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 29.19%
# Recall@1: 29.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 42.21%
# Recall@3: 42.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 48.51%
# Recall@5: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 56.41%
# Recall@10: 56.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3736
# MRR@10: 0.3736
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4190
# NDCG@10: 0.4190
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.3850
# MAP@100: 0.3850
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 300 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 300 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 31.29%
# Accuracy@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 44.21%
# Accuracy@3: 44.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 50.59%
# Accuracy@5: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 58.94%
# Accuracy@10: 58.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 31.29%
# Precision@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 14.74%
# Precision@3: 14.74%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.12%
# Precision@5: 10.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.89%
# Precision@10: 5.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 31.29%
# Recall@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 44.21%
# Recall@3: 44.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 50.59%
# Recall@5: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 58.94%
# Recall@10: 58.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3952
# MRR@10: 0.3952
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4413
# NDCG@10: 0.4413
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4058
# MAP@100: 0.4058
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 31.29%
# Accuracy@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 44.21%
# Accuracy@3: 44.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 50.59%
# Accuracy@5: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 58.94%
# Accuracy@10: 58.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 31.29%
# Precision@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 14.74%
# Precision@3: 14.74%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.12%
# Precision@5: 10.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 5.89%
# Precision@10: 5.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 31.29%
# Recall@1: 31.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 44.21%
# Recall@3: 44.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 50.59%
# Recall@5: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 58.94%
# Recall@10: 58.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.3952
# MRR@10: 0.3952
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4413
# NDCG@10: 0.4413
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4058
# MAP@100: 0.4058
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 350 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 350 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 32.54%
# Accuracy@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 45.84%
# Accuracy@3: 45.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 52.31%
# Accuracy@5: 52.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 60.88%
# Accuracy@10: 60.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 32.54%
# Precision@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.28%
# Precision@3: 15.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.46%
# Precision@5: 10.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.09%
# Precision@10: 6.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 32.54%
# Recall@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 45.84%
# Recall@3: 45.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 52.31%
# Recall@5: 52.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 60.88%
# Recall@10: 60.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4100
# MRR@10: 0.4100
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4573
# NDCG@10: 0.4573
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4205
# MAP@100: 0.4205
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 32.54%
# Accuracy@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 45.84%
# Accuracy@3: 45.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 52.31%
# Accuracy@5: 52.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 60.88%
# Accuracy@10: 60.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 32.54%
# Precision@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.28%
# Precision@3: 15.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.46%
# Precision@5: 10.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.09%
# Precision@10: 6.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 32.54%
# Recall@1: 32.54%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 45.84%
# Recall@3: 45.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 52.31%
# Recall@5: 52.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 60.88%
# Recall@10: 60.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4100
# MRR@10: 0.4100
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4573
# NDCG@10: 0.4573
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4205
# MAP@100: 0.4205
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 400 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 400 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 32.92%
# Accuracy@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 46.84%
# Accuracy@3: 46.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 53.29%
# Accuracy@5: 53.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 61.81%
# Accuracy@10: 61.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 32.92%
# Precision@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.61%
# Precision@3: 15.61%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.66%
# Precision@5: 10.66%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.18%
# Precision@10: 6.18%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 32.92%
# Recall@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 46.84%
# Recall@3: 46.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 53.29%
# Recall@5: 53.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 61.81%
# Recall@10: 61.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4159
# MRR@10: 0.4159
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4641
# NDCG@10: 0.4641
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4264
# MAP@100: 0.4264
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 32.92%
# Accuracy@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 46.81%
# Accuracy@3: 46.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 53.29%
# Accuracy@5: 53.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 61.78%
# Accuracy@10: 61.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 32.92%
# Precision@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.60%
# Precision@3: 15.60%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.66%
# Precision@5: 10.66%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.18%
# Precision@10: 6.18%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 32.92%
# Recall@1: 32.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 46.81%
# Recall@3: 46.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 53.29%
# Recall@5: 53.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 61.78%
# Recall@10: 61.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4159
# MRR@10: 0.4159
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4640
# NDCG@10: 0.4640
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4265
# MAP@100: 0.4265
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 450 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 450 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 33.37%
# Accuracy@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 47.86%
# Accuracy@3: 47.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 54.69%
# Accuracy@5: 54.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 63.41%
# Accuracy@10: 63.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 33.37%
# Precision@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.95%
# Precision@3: 15.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.94%
# Precision@5: 10.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.34%
# Precision@10: 6.34%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 33.37%
# Recall@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 47.86%
# Recall@3: 47.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 54.69%
# Recall@5: 54.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 63.41%
# Recall@10: 63.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4239
# MRR@10: 0.4239
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4739
# NDCG@10: 0.4739
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4338
# MAP@100: 0.4338
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 33.37%
# Accuracy@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 47.86%
# Accuracy@3: 47.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 54.69%
# Accuracy@5: 54.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 63.41%
# Accuracy@10: 63.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 33.37%
# Precision@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 15.95%
# Precision@3: 15.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 10.94%
# Precision@5: 10.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.34%
# Precision@10: 6.34%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 33.37%
# Recall@1: 33.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 47.86%
# Recall@3: 47.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 54.69%
# Recall@5: 54.69%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 63.41%
# Recall@10: 63.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4239
# MRR@10: 0.4239
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4740
# NDCG@10: 0.4740
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4339
# MAP@100: 0.4339
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 500 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 500 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 33.97%
# Accuracy@1: 33.97%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 48.51%
# Accuracy@3: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 55.26%
# Accuracy@5: 55.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.01%
# Accuracy@10: 64.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 33.97%
# Precision@1: 33.97%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.17%
# Precision@3: 16.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.05%
# Precision@5: 11.05%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.40%
# Precision@10: 6.40%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 33.97%
# Recall@1: 33.97%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 48.51%
# Recall@3: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 55.26%
# Recall@5: 55.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.01%
# Recall@10: 64.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4301
# MRR@10: 0.4301
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4802
# NDCG@10: 0.4802
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4405
# MAP@100: 0.4405
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 33.94%
# Accuracy@1: 33.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 48.51%
# Accuracy@3: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 55.26%
# Accuracy@5: 55.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.01%
# Accuracy@10: 64.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 33.94%
# Precision@1: 33.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.17%
# Precision@3: 16.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.05%
# Precision@5: 11.05%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.40%
# Precision@10: 6.40%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 33.94%
# Recall@1: 33.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 48.51%
# Recall@3: 48.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 55.26%
# Recall@5: 55.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.01%
# Recall@10: 64.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4299
# MRR@10: 0.4299
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4800
# NDCG@10: 0.4800
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4404
# MAP@100: 0.4404
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 550 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 550 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 35.09%
# Accuracy@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 49.84%
# Accuracy@3: 49.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 56.39%
# Accuracy@5: 56.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.91%
# Accuracy@10: 64.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 35.09%
# Precision@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.61%
# Precision@3: 16.61%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.28%
# Precision@5: 11.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.49%
# Precision@10: 6.49%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 35.09%
# Recall@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 49.84%
# Recall@3: 49.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 56.39%
# Recall@5: 56.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.91%
# Recall@10: 64.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4420
# MRR@10: 0.4420
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4914
# NDCG@10: 0.4914
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4521
# MAP@100: 0.4521
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 35.09%
# Accuracy@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 49.84%
# Accuracy@3: 49.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 56.41%
# Accuracy@5: 56.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.91%
# Accuracy@10: 64.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 35.09%
# Precision@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.61%
# Precision@3: 16.61%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.28%
# Precision@5: 11.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.49%
# Precision@10: 6.49%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 35.09%
# Recall@1: 35.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 49.84%
# Recall@3: 49.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 56.41%
# Recall@5: 56.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.91%
# Recall@10: 64.91%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4420
# MRR@10: 0.4420
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4915
# NDCG@10: 0.4915
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4521
# MAP@100: 0.4521
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 600 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 600 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 35.87%
# Accuracy@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 50.59%
# Accuracy@3: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 56.96%
# Accuracy@5: 56.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.96%
# Accuracy@10: 64.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 35.87%
# Precision@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.86%
# Precision@3: 16.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.39%
# Precision@5: 11.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.50%
# Precision@10: 6.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 35.87%
# Recall@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 50.59%
# Recall@3: 50.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 56.96%
# Recall@5: 56.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.96%
# Recall@10: 64.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4481
# MRR@10: 0.4481
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4962
# NDCG@10: 0.4962
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4583
# MAP@100: 0.4583
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 35.87%
# Accuracy@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 50.61%
# Accuracy@3: 50.61%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 56.96%
# Accuracy@5: 56.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 64.96%
# Accuracy@10: 64.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 35.87%
# Precision@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 16.87%
# Precision@3: 16.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 11.39%
# Precision@5: 11.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.50%
# Precision@10: 6.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 35.87%
# Recall@1: 35.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 50.61%
# Recall@3: 50.61%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 56.96%
# Recall@5: 56.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 64.96%
# Recall@10: 64.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4481
# MRR@10: 0.4481
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.4963
# NDCG@10: 0.4963
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4584
# MAP@100: 0.4584
# INFO:sentence_transformers.SentenceTransformer:Save model to ./data/finetune_embedding/finetuned_model
# Save model to ./data/finetune_embedding/finetuned_model
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 650 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0 after 650 steps:
# ...
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.39%
# Recall@1: 39.39%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.76%
# Recall@3: 54.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.03%
# Recall@5: 61.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.26%
# Recall@10: 69.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4866
# MRR@10: 0.4866
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5358
# NDCG@10: 0.5358
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4966
# MAP@100: 0.4966
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1450 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1450 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.37%
# Accuracy@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.81%
# Accuracy@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.08%
# Accuracy@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.43%
# Accuracy@10: 69.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.37%
# Precision@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.27%
# Precision@3: 18.27%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.94%
# Precision@10: 6.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.37%
# Recall@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.81%
# Recall@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.08%
# Recall@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.43%
# Recall@10: 69.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4868
# MRR@10: 0.4868
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5364
# NDCG@10: 0.5364
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4967
# MAP@100: 0.4967
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.37%
# Accuracy@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.81%
# Accuracy@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.08%
# Accuracy@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.43%
# Accuracy@10: 69.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.37%
# Precision@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.27%
# Precision@3: 18.27%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.94%
# Precision@10: 6.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.37%
# Recall@1: 39.37%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.81%
# Recall@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.08%
# Recall@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.43%
# Recall@10: 69.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4868
# MRR@10: 0.4868
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5364
# NDCG@10: 0.5364
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4967
# MAP@100: 0.4967
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1500 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1500 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.32%
# Accuracy@1: 39.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.79%
# Accuracy@3: 54.79%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.08%
# Accuracy@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.32%
# Precision@1: 39.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.26%
# Precision@3: 18.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.32%
# Recall@1: 39.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.79%
# Recall@3: 54.79%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.08%
# Recall@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4865
# MRR@10: 0.4865
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5362
# NDCG@10: 0.5362
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4964
# MAP@100: 0.4964
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.34%
# Accuracy@1: 39.34%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.81%
# Accuracy@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.11%
# Accuracy@5: 61.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.34%
# Precision@1: 39.34%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.27%
# Precision@3: 18.27%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.34%
# Recall@1: 39.34%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.81%
# Recall@3: 54.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.11%
# Recall@5: 61.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4867
# MRR@10: 0.4867
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5364
# NDCG@10: 0.5364
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4966
# MAP@100: 0.4966
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1550 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1 after 1550 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.29%
# Accuracy@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.84%
# Accuracy@3: 54.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.13%
# Accuracy@5: 61.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.29%
# Precision@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.28%
# Precision@3: 18.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.23%
# Precision@5: 12.23%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.29%
# Recall@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.84%
# Recall@3: 54.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.13%
# Recall@5: 61.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4866
# MRR@10: 0.4866
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5363
# NDCG@10: 0.5363
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4965
# MAP@100: 0.4965
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.29%
# Accuracy@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.84%
# Accuracy@3: 54.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.13%
# Accuracy@5: 61.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.29%
# Precision@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.28%
# Precision@3: 18.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.23%
# Precision@5: 12.23%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.29%
# Recall@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.84%
# Recall@3: 54.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.13%
# Recall@5: 61.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4866
# MRR@10: 0.4866
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5363
# NDCG@10: 0.5363
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4965
# MAP@100: 0.4965
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset after epoch 1:
# Information Retrieval Evaluation of the model on the  dataset after epoch 1:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 4001
# Queries: 4001
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 4001
#
# Corpus: 4001
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cos_sim
# Score-Function: cos_sim
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.29%
# Accuracy@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.86%
# Accuracy@3: 54.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.11%
# Accuracy@5: 61.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.29%
# Precision@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.29%
# Precision@3: 18.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.29%
# Recall@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.86%
# Recall@3: 54.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.11%
# Recall@5: 61.11%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4866
# MRR@10: 0.4866
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5363
# NDCG@10: 0.5363
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4966
# MAP@100: 0.4966
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: dot_score
# Score-Function: dot_score
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 39.29%
# Accuracy@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 54.86%
# Accuracy@3: 54.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 61.08%
# Accuracy@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 69.46%
# Accuracy@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 39.29%
# Precision@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 18.29%
# Precision@3: 18.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 12.22%
# Precision@5: 12.22%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 6.95%
# Precision@10: 6.95%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 39.29%
# Recall@1: 39.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 54.86%
# Recall@3: 54.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 61.08%
# Recall@5: 61.08%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 69.46%
# Recall@10: 69.46%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.4866
# MRR@10: 0.4866
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5363
# NDCG@10: 0.5363
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.4965
# MAP@100: 0.4965
# CPU times: user 31min 29s, sys: 1min 54s, total: 33min 24s
# Wall time: 30min 56s

# %%
embed_model = finetune_engine.get_finetuned_model()
embed_model
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: ./data/finetune_embedding/finetuned_model
# Load pretrained SentenceTransformer: ./data/finetune_embedding/finetuned_model
# WARNING:sentence_transformers.SentenceTransformer:You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# INFO:sentence_transformers.SentenceTransformer:2 prompts are loaded, with the keys: ['query', 'text']
# 2 prompts are loaded, with the keys: ['query', 'text']
# HuggingFaceEmbedding(model_name='./data/finetune_embedding/finetuned_model', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7b4a21638690>, num_workers=None, max_length=512, normalize=True, query_instruction=None, text_instruction=None, cache_folder=None)

# %% [markdown]
# # Evaluate

# %%
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers import SentenceTransformer
from pathlib import Path
import shutil

def evaluate_st(
    dataset,
    model_id,
    name,
    output_path: str = None
):
    corpus = dataset.corpus
    queries = dataset.queries
    relevant_docs = dataset.relevant_docs

    evaluator = InformationRetrievalEvaluator(
        queries, corpus, relevant_docs, name=name
    )

    model = SentenceTransformer(model_id)

    if os.path.exists(output_path):
        shutil.rmtree(output_path)
    Path(output_path).mkdir(exist_ok=True, parents=True)
    return evaluator(model, output_path=output_path)

# %%
name = 'bge'
model_id = "BAAI/bge-large-en"
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
bge_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: BAAI/bge-large-en
# Load pretrained SentenceTransformer: BAAI/bge-large-en
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Use pytorch device_name: cuda
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the bge dataset:
# Information Retrieval Evaluation of the model on the bge dataset:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[33], line 5
#       3 output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
#       4 output_path = f"{cfg.eval_dp}/{name}"
# ----> 5 evaluate_st(val_dataset, model_id, name, output_path=output_path)
#       6 bge_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
#
# Cell In[32], line 25, in evaluate_st(dataset, model_id, name, output_path)
#      23     shutil.rmtree(output_path)
#      24 Path(output_path).mkdir(exist_ok=True, parents=True)
# ---> 25 return evaluator(model, output_path=output_path)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:113, in InformationRetrievalEvaluator.__call__(self, model, output_path, epoch, steps, *args, **kwargs)
#     109     out_txt += f" (truncated to {self.truncate_dim})"
#     111 logger.info(f"Information Retrieval Evaluation of the model on the {self.name} dataset{out_txt}:")
# --> 113 scores = self.compute_metrices(model, *args, **kwargs)
#     115 # Write results to disc
#     116 if output_path is not None and self.write_csv:
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:191, in InformationRetrievalEvaluator.compute_metrices(self, model, corpus_model, corpus_embeddings)
#     187 if corpus_embeddings is None:
#     188     with nullcontext() if self.truncate_dim is None else corpus_model.truncate_sentence_embeddings(
#     189         self.truncate_dim
#     190     ):
# --> 191         sub_corpus_embeddings = corpus_model.encode(
#     192             self.corpus[corpus_start_idx:corpus_end_idx],
#     193             show_progress_bar=False,
#     194             batch_size=self.batch_size,
#     195             convert_to_tensor=True,
#     196         )
#     197 else:
#     198     sub_corpus_embeddings = corpus_embeddings[corpus_start_idx:corpus_end_idx]
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:371, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     368 features.update(extra_features)
#     370 with torch.no_grad():
# --> 371     out_features = self.forward(features)
#     372     out_features["sentence_embedding"] = truncate_embeddings(
#     373         out_features["sentence_embedding"], self.truncate_dim
#     374     )
#     376     if output_value == "token_embeddings":
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:98, in Transformer.forward(self, features)
#      95 if "token_type_ids" in features:
#      96     trans_features["token_type_ids"] = features["token_type_ids"]
# ---> 98 output_states = self.auto_model(**trans_features, return_dict=False)
#      99 output_tokens = output_states[0]
#     101 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:1141, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1134 # Prepare head mask if needed
#    1135 # 1.0 in head_mask indicate we keep the head
#    1136 # attention_probs has shape bsz x n_heads x N x N
#    1137 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1138 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1139 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1141 encoder_outputs = self.encoder(
#    1142     embedding_output,
#    1143     attention_mask=extended_attention_mask,
#    1144     head_mask=head_mask,
#    1145     encoder_hidden_states=encoder_hidden_states,
#    1146     encoder_attention_mask=encoder_extended_attention_mask,
#    1147     past_key_values=past_key_values,
#    1148     use_cache=use_cache,
#    1149     output_attentions=output_attentions,
#    1150     output_hidden_states=output_hidden_states,
#    1151     return_dict=return_dict,
#    1152 )
#    1153 sequence_output = encoder_outputs[0]
#    1154 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:694, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     683     layer_outputs = self._gradient_checkpointing_func(
#     684         layer_module.__call__,
#     685         hidden_states,
#    (...)
#     691         output_attentions,
#     692     )
#     693 else:
# --> 694     layer_outputs = layer_module(
#     695         hidden_states,
#     696         attention_mask,
#     697         layer_head_mask,
#     698         encoder_hidden_states,
#     699         encoder_attention_mask,
#     700         past_key_value,
#     701         output_attentions,
#     702     )
#     704 hidden_states = layer_outputs[0]
#     705 if use_cache:
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:626, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     623     cross_attn_present_key_value = cross_attention_outputs[-1]
#     624     present_key_value = present_key_value + cross_attn_present_key_value
# --> 626 layer_output = apply_chunking_to_forward(
#     627     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     628 )
#     629 outputs = (layer_output,) + outputs
#     631 # if decoder, return the attn key/values as the last output
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/pytorch_utils.py:238, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     235     # concatenate output at same dimension
#     236     return torch.cat(output_chunks, dim=chunk_dim)
# --> 238 return forward_fn(*input_tensors)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:638, in BertLayer.feed_forward_chunk(self, attention_output)
#     637 def feed_forward_chunk(self, attention_output):
# --> 638     intermediate_output = self.intermediate(attention_output)
#     639     layer_output = self.output(intermediate_output, attention_output)
#     640     return layer_output
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:539, in BertIntermediate.forward(self, hidden_states)
#     537 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     538     hidden_states = self.dense(hidden_states)
# --> 539     hidden_states = self.intermediate_act_fn(hidden_states)
#     540     return hidden_states
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/activations.py:78, in GELUActivation.forward(self, input)
#      77 def forward(self, input: Tensor) -> Tensor:
# ---> 78     return self.act(input)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 256.00 MiB. GPU 0 has a total capacity of 3.72 GiB of which 152.00 MiB is free. Including non-PyTorch memory, this process has 3.49 GiB memory in use. Of the allocated memory 2.98 GiB is allocated by PyTorch, and 413.31 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
bge_eval_results

# %%
name = 'finetuned'
model_id = cfg.ft_model_dp
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
ft_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: ./data/finetune_embedding/finetuned_model
# Load pretrained SentenceTransformer: ./data/finetune_embedding/finetuned_model
# WARNING:sentence_transformers.SentenceTransformer:You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:1 prompts are loaded, with the keys: ['query']
# 1 prompts are loaded, with the keys: ['query']
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the finetuned dataset:
# Information Retrieval Evaluation of the model on the finetuned dataset:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[34], line 5
#       3 output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
#       4 output_path = f"{cfg.eval_dp}/{name}"
# ----> 5 evaluate_st(val_dataset, model_id, name, output_path=output_path)
#       6 ft_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
#
# Cell In[32], line 25, in evaluate_st(dataset, model_id, name, output_path)
#      23     shutil.rmtree(output_path)
#      24 Path(output_path).mkdir(exist_ok=True, parents=True)
# ---> 25 return evaluator(model, output_path=output_path)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:113, in InformationRetrievalEvaluator.__call__(self, model, output_path, epoch, steps, *args, **kwargs)
#     109     out_txt += f" (truncated to {self.truncate_dim})"
#     111 logger.info(f"Information Retrieval Evaluation of the model on the {self.name} dataset{out_txt}:")
# --> 113 scores = self.compute_metrices(model, *args, **kwargs)
#     115 # Write results to disc
#     116 if output_path is not None and self.write_csv:
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:169, in InformationRetrievalEvaluator.compute_metrices(self, model, corpus_model, corpus_embeddings)
#     167 # Compute embedding for the queries
#     168 with nullcontext() if self.truncate_dim is None else model.truncate_sentence_embeddings(self.truncate_dim):
# --> 169     query_embeddings = model.encode(
#     170         self.queries,
#     171         show_progress_bar=self.show_progress_bar,
#     172         batch_size=self.batch_size,
#     173         convert_to_tensor=True,
#     174     )
#     176 queries_result_list = {}
#     177 for name in self.score_functions:
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:371, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     368 features.update(extra_features)
#     370 with torch.no_grad():
# --> 371     out_features = self.forward(features)
#     372     out_features["sentence_embedding"] = truncate_embeddings(
#     373         out_features["sentence_embedding"], self.truncate_dim
#     374     )
#     376     if output_value == "token_embeddings":
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:98, in Transformer.forward(self, features)
#      95 if "token_type_ids" in features:
#      96     trans_features["token_type_ids"] = features["token_type_ids"]
# ---> 98 output_states = self.auto_model(**trans_features, return_dict=False)
#      99 output_tokens = output_states[0]
#     101 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:1141, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1134 # Prepare head mask if needed
#    1135 # 1.0 in head_mask indicate we keep the head
#    1136 # attention_probs has shape bsz x n_heads x N x N
#    1137 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1138 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1139 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1141 encoder_outputs = self.encoder(
#    1142     embedding_output,
#    1143     attention_mask=extended_attention_mask,
#    1144     head_mask=head_mask,
#    1145     encoder_hidden_states=encoder_hidden_states,
#    1146     encoder_attention_mask=encoder_extended_attention_mask,
#    1147     past_key_values=past_key_values,
#    1148     use_cache=use_cache,
#    1149     output_attentions=output_attentions,
#    1150     output_hidden_states=output_hidden_states,
#    1151     return_dict=return_dict,
#    1152 )
#    1153 sequence_output = encoder_outputs[0]
#    1154 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:694, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     683     layer_outputs = self._gradient_checkpointing_func(
#     684         layer_module.__call__,
#     685         hidden_states,
#    (...)
#     691         output_attentions,
#     692     )
#     693 else:
# --> 694     layer_outputs = layer_module(
#     695         hidden_states,
#     696         attention_mask,
#     697         layer_head_mask,
#     698         encoder_hidden_states,
#     699         encoder_attention_mask,
#     700         past_key_value,
#     701         output_attentions,
#     702     )
#     704 hidden_states = layer_outputs[0]
#     705 if use_cache:
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:626, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     623     cross_attn_present_key_value = cross_attention_outputs[-1]
#     624     present_key_value = present_key_value + cross_attn_present_key_value
# --> 626 layer_output = apply_chunking_to_forward(
#     627     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     628 )
#     629 outputs = (layer_output,) + outputs
#     631 # if decoder, return the attn key/values as the last output
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/pytorch_utils.py:238, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     235     # concatenate output at same dimension
#     236     return torch.cat(output_chunks, dim=chunk_dim)
# --> 238 return forward_fn(*input_tensors)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:638, in BertLayer.feed_forward_chunk(self, attention_output)
#     637 def feed_forward_chunk(self, attention_output):
# --> 638     intermediate_output = self.intermediate(attention_output)
#     639     layer_output = self.output(intermediate_output, attention_output)
#     640     return layer_output
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:539, in BertIntermediate.forward(self, hidden_states)
#     537 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     538     hidden_states = self.dense(hidden_states)
# --> 539     hidden_states = self.intermediate_act_fn(hidden_states)
#     540     return hidden_states
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/frostmourne/study/vietai-genai03/final-project/review-rec-bot/.venv/lib/python3.11/site-packages/transformers/activations.py:78, in GELUActivation.forward(self, input)
#      77 def forward(self, input: Tensor) -> Tensor:
# ---> 78     return self.act(input)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 12.00 MiB. GPU 0 has a total capacity of 3.72 GiB of which 12.00 MiB is free. Including non-PyTorch memory, this process has 3.63 GiB memory in use. Of the allocated memory 3.41 GiB is allocated by PyTorch, and 116.72 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
ft_eval_results

# %%
name = 'arctic'
model_id = "Snowflake/snowflake-arctic-embed-m-v1.5"
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
arctic_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")

# %%
arctic_eval_results

# %%
eval_df = pd.concat([
    pd.Series(arctic_eval_results.loc[0], name='arctic'),
    pd.Series(bge_eval_results.loc[0], name='bge'),
    pd.Series(ft_eval_results.loc[0], name='ft'),
], axis=1)

(
    eval_df
    .style
    .background_gradient(axis=1, low=0, high=1)
)

# %% [markdown]
# # Archive

# %% [raw]
# # sample_dataset = generate_qa_embedding_pairs(
# #     llm=llm,
# #     nodes=sample_nodes,
# #     qa_generate_prompt_tmpl=gen_query_prompt_tmpl,
# #     num_questions_per_chunk=1,
# #     output_path=output_path,
# #     save_every=10,
# #     verbose=False
# # )
