# %% [markdown]
# # Evaluate Finetuned Embed Model

# %%
import os
import pandas as pd
import torch
import gc

# %%
from pydantic import BaseModel

class Config(BaseModel):
    testing: bool = False

    data_fp: str = "../data/yelp_dataset/sample/sample_100_biz/denom_review.parquet"
    storage_context_persist_dp: str = "./data/finetune_embedding/storage_context"
    gen_qa_embedding_pairs_dp: str = "./data/finetune_embedding/gen_qa_embedding_pairs"
    ft_model_dp: str = "./data/finetune_embedding/finetuned_model"
    eval_dp: str = "./data/finetune_embedding/eval"

    num_questions_per_chunk: int = 2

cfg = Config()

# %%
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers import SentenceTransformer
from pathlib import Path
import shutil

def evaluate_st(
    dataset,
    model_id,
    name,
    output_path: str = None
):
    corpus = dataset.corpus
    queries = dataset.queries
    relevant_docs = dataset.relevant_docs

    evaluator = InformationRetrievalEvaluator(
        queries, corpus, relevant_docs, name=name
    )

    model = SentenceTransformer(model_id)

    if os.path.exists(output_path):
        shutil.rmtree(output_path)
    Path(output_path).mkdir(exist_ok=True, parents=True)
    
    result = evaluator(model, output_path=output_path)

    # Clear GPU memory
    del model
    torch.cuda.empty_cache()
    gc.collect()

    return result

# %%
from llama_index.core.evaluation import EmbeddingQAFinetuneDataset

val_output_path = f"{cfg.gen_qa_embedding_pairs_dp}/val/qa_finetuned_dataset.json"
val_dataset = EmbeddingQAFinetuneDataset.from_json(val_output_path)

# %%
# %%time
name = 'finetuned'
model_id = cfg.ft_model_dp
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
ft_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
# Out:
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# CPU times: user 22.2 s, sys: 1.07 s, total: 23.3 s
# Wall time: 21.2 s

# %%
ft_eval_results.T
# Out:
#                                0
# epoch                  -1.000000
# steps                  -1.000000
# cos_sim-Accuracy@1      0.398400
# cos_sim-Accuracy@3      0.544364
# cos_sim-Accuracy@5      0.612347
# cos_sim-Accuracy@10     0.693327
# cos_sim-Precision@1     0.398400
# cos_sim-Recall@1        0.398400
# cos_sim-Precision@3     0.181455
# cos_sim-Recall@3        0.544364
# cos_sim-Precision@5     0.122469
# cos_sim-Recall@5        0.612347
# cos_sim-Precision@10    0.069333
# cos_sim-Recall@10       0.693327
# cos_sim-MRR@10          0.489804
# cos_sim-NDCG@10         0.538471
# cos_sim-MAP@100         0.499643
# dot_score-Accuracy@1    0.398400
# dot_score-Accuracy@3    0.544364
# dot_score-Accuracy@5    0.612347
# dot_score-Accuracy@10   0.693577
# dot_score-Precision@1   0.398400
# dot_score-Recall@1      0.398400
# dot_score-Precision@3   0.181455
# dot_score-Recall@3      0.544364
# dot_score-Precision@5   0.122469
# dot_score-Recall@5      0.612347
# dot_score-Precision@10  0.069358
# dot_score-Recall@10     0.693577
# dot_score-MRR@10        0.489829
# dot_score-NDCG@10       0.538543
# dot_score-MAP@100       0.499645

# %%
# %%time
name = 'bge'
model_id = "BAAI/bge-large-en"
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
bge_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
# Out:
# CPU times: user 1min 5s, sys: 828 ms, total: 1min 5s
# Wall time: 1min 8s

# %%
bge_eval_results.T
# Out:
#                                0
# epoch                  -1.000000
# steps                  -1.000000
# cos_sim-Accuracy@1      0.169708
# cos_sim-Accuracy@3      0.265434
# cos_sim-Accuracy@5      0.318920
# cos_sim-Accuracy@10     0.395151
# cos_sim-Precision@1     0.169708
# cos_sim-Recall@1        0.169708
# cos_sim-Precision@3     0.088478
# cos_sim-Recall@3        0.265434
# cos_sim-Precision@5     0.063784
# cos_sim-Recall@5        0.318920
# cos_sim-Precision@10    0.039515
# cos_sim-Recall@10       0.395151
# cos_sim-MRR@10          0.233948
# cos_sim-NDCG@10         0.272030
# cos_sim-MAP@100         0.244684
# dot_score-Accuracy@1    0.169708
# dot_score-Accuracy@3    0.265434
# dot_score-Accuracy@5    0.318920
# dot_score-Accuracy@10   0.395151
# dot_score-Precision@1   0.169708
# dot_score-Recall@1      0.169708
# dot_score-Precision@3   0.088478
# dot_score-Recall@3      0.265434
# dot_score-Precision@5   0.063784
# dot_score-Recall@5      0.318920
# dot_score-Precision@10  0.039515
# dot_score-Recall@10     0.395151
# dot_score-MRR@10        0.233948
# dot_score-NDCG@10       0.272030
# dot_score-MAP@100       0.244684

# %%
name = 'arctic'
model_id = "Snowflake/snowflake-arctic-embed-m-v1.5"
output_csv_filename = f"Information-Retrieval_evaluation_{name}_results.csv"
output_path = f"{cfg.eval_dp}/{name}"
evaluate_st(val_dataset, model_id, name, output_path=output_path)
arctic_eval_results = pd.read_csv(f"{output_path}/{output_csv_filename}")
# Out:
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# Some weights of BertModel were not initialized from the model checkpoint at Snowflake/snowflake-arctic-embed-m-v1.5 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
arctic_eval_results
# Out:
#    epoch  steps  cos_sim-Accuracy@1  cos_sim-Accuracy@3  cos_sim-Accuracy@5  \
# 0     -1     -1            0.122719            0.187453            0.226943
#
#    cos_sim-Accuracy@10  cos_sim-Precision@1  cos_sim-Recall@1  \
# 0             0.284679             0.122719          0.122719
#
#    cos_sim-Precision@3  cos_sim-Recall@3  ...  dot_score-Recall@1  \
# 0             0.062484          0.187453  ...            0.122719
#
#    dot_score-Precision@3  dot_score-Recall@3  dot_score-Precision@5  \
# 0               0.062484            0.187453               0.045389
#
#    dot_score-Recall@5  dot_score-Precision@10  dot_score-Recall@10  \
# 0            0.226943                0.028468             0.284679
#
#    dot_score-MRR@10  dot_score-NDCG@10  dot_score-MAP@100
# 0          0.167267           0.194887           0.174883
#
# [1 rows x 32 columns]

# %%
eval_df = pd.concat([
    pd.Series(arctic_eval_results.loc[0], name='arctic'),
    pd.Series(bge_eval_results.loc[0], name='bge'),
    pd.Series(ft_eval_results.loc[0], name='ft'),
], axis=1)

(
    eval_df
    .style
    .background_gradient(axis=1, low=0, high=1)
)
# Out:
# <style type="text/css">
# #T_80259_row0_col0, #T_80259_row0_col1, #T_80259_row0_col2, #T_80259_row1_col0, #T_80259_row1_col1, #T_80259_row1_col2, #T_80259_row2_col0, #T_80259_row3_col0, #T_80259_row4_col0, #T_80259_row5_col0, #T_80259_row6_col0, #T_80259_row7_col0, #T_80259_row8_col0, #T_80259_row9_col0, #T_80259_row10_col0, #T_80259_row11_col0, #T_80259_row12_col0, #T_80259_row13_col0, #T_80259_row14_col0, #T_80259_row15_col0, #T_80259_row16_col0, #T_80259_row17_col0, #T_80259_row18_col0, #T_80259_row19_col0, #T_80259_row20_col0, #T_80259_row21_col0, #T_80259_row22_col0, #T_80259_row23_col0, #T_80259_row24_col0, #T_80259_row25_col0, #T_80259_row26_col0, #T_80259_row27_col0, #T_80259_row28_col0, #T_80259_row29_col0, #T_80259_row30_col0, #T_80259_row31_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_80259_row2_col1, #T_80259_row6_col1, #T_80259_row7_col1, #T_80259_row17_col1, #T_80259_row21_col1, #T_80259_row22_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_80259_row2_col2, #T_80259_row3_col2, #T_80259_row5_col2, #T_80259_row6_col2, #T_80259_row7_col2, #T_80259_row9_col2, #T_80259_row10_col2, #T_80259_row12_col2, #T_80259_row13_col2, #T_80259_row14_col2, #T_80259_row15_col2, #T_80259_row16_col2, #T_80259_row17_col2, #T_80259_row18_col2, #T_80259_row20_col2, #T_80259_row21_col2, #T_80259_row22_col2, #T_80259_row24_col2, #T_80259_row25_col2, #T_80259_row27_col2, #T_80259_row28_col2, #T_80259_row29_col2, #T_80259_row30_col2, #T_80259_row31_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_80259_row3_col1, #T_80259_row8_col1, #T_80259_row9_col1, #T_80259_row16_col1, #T_80259_row18_col1, #T_80259_row23_col1, #T_80259_row24_col1, #T_80259_row31_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_80259_row4_col1, #T_80259_row10_col1, #T_80259_row11_col1, #T_80259_row19_col1, #T_80259_row25_col1, #T_80259_row26_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_80259_row4_col2, #T_80259_row8_col2, #T_80259_row11_col2, #T_80259_row19_col2, #T_80259_row23_col2, #T_80259_row26_col2 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_80259_row5_col1, #T_80259_row12_col1, #T_80259_row13_col1, #T_80259_row20_col1, #T_80259_row27_col1, #T_80259_row28_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_80259_row14_col1, #T_80259_row29_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_80259_row15_col1, #T_80259_row30_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# </style>
# <table id="T_80259">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80259_level0_col0" class="col_heading level0 col0" >arctic</th>
#       <th id="T_80259_level0_col1" class="col_heading level0 col1" >bge</th>
#       <th id="T_80259_level0_col2" class="col_heading level0 col2" >ft</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80259_level0_row0" class="row_heading level0 row0" >epoch</th>
#       <td id="T_80259_row0_col0" class="data row0 col0" >-1.000000</td>
#       <td id="T_80259_row0_col1" class="data row0 col1" >-1.000000</td>
#       <td id="T_80259_row0_col2" class="data row0 col2" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row1" class="row_heading level0 row1" >steps</th>
#       <td id="T_80259_row1_col0" class="data row1 col0" >-1.000000</td>
#       <td id="T_80259_row1_col1" class="data row1 col1" >-1.000000</td>
#       <td id="T_80259_row1_col2" class="data row1 col2" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row2" class="row_heading level0 row2" >cos_sim-Accuracy@1</th>
#       <td id="T_80259_row2_col0" class="data row2 col0" >0.122719</td>
#       <td id="T_80259_row2_col1" class="data row2 col1" >0.169708</td>
#       <td id="T_80259_row2_col2" class="data row2 col2" >0.398400</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row3" class="row_heading level0 row3" >cos_sim-Accuracy@3</th>
#       <td id="T_80259_row3_col0" class="data row3 col0" >0.187453</td>
#       <td id="T_80259_row3_col1" class="data row3 col1" >0.265434</td>
#       <td id="T_80259_row3_col2" class="data row3 col2" >0.544364</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row4" class="row_heading level0 row4" >cos_sim-Accuracy@5</th>
#       <td id="T_80259_row4_col0" class="data row4 col0" >0.226943</td>
#       <td id="T_80259_row4_col1" class="data row4 col1" >0.318920</td>
#       <td id="T_80259_row4_col2" class="data row4 col2" >0.612347</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row5" class="row_heading level0 row5" >cos_sim-Accuracy@10</th>
#       <td id="T_80259_row5_col0" class="data row5 col0" >0.284679</td>
#       <td id="T_80259_row5_col1" class="data row5 col1" >0.395151</td>
#       <td id="T_80259_row5_col2" class="data row5 col2" >0.693327</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row6" class="row_heading level0 row6" >cos_sim-Precision@1</th>
#       <td id="T_80259_row6_col0" class="data row6 col0" >0.122719</td>
#       <td id="T_80259_row6_col1" class="data row6 col1" >0.169708</td>
#       <td id="T_80259_row6_col2" class="data row6 col2" >0.398400</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row7" class="row_heading level0 row7" >cos_sim-Recall@1</th>
#       <td id="T_80259_row7_col0" class="data row7 col0" >0.122719</td>
#       <td id="T_80259_row7_col1" class="data row7 col1" >0.169708</td>
#       <td id="T_80259_row7_col2" class="data row7 col2" >0.398400</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row8" class="row_heading level0 row8" >cos_sim-Precision@3</th>
#       <td id="T_80259_row8_col0" class="data row8 col0" >0.062484</td>
#       <td id="T_80259_row8_col1" class="data row8 col1" >0.088478</td>
#       <td id="T_80259_row8_col2" class="data row8 col2" >0.181455</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row9" class="row_heading level0 row9" >cos_sim-Recall@3</th>
#       <td id="T_80259_row9_col0" class="data row9 col0" >0.187453</td>
#       <td id="T_80259_row9_col1" class="data row9 col1" >0.265434</td>
#       <td id="T_80259_row9_col2" class="data row9 col2" >0.544364</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row10" class="row_heading level0 row10" >cos_sim-Precision@5</th>
#       <td id="T_80259_row10_col0" class="data row10 col0" >0.045389</td>
#       <td id="T_80259_row10_col1" class="data row10 col1" >0.063784</td>
#       <td id="T_80259_row10_col2" class="data row10 col2" >0.122469</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row11" class="row_heading level0 row11" >cos_sim-Recall@5</th>
#       <td id="T_80259_row11_col0" class="data row11 col0" >0.226943</td>
#       <td id="T_80259_row11_col1" class="data row11 col1" >0.318920</td>
#       <td id="T_80259_row11_col2" class="data row11 col2" >0.612347</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row12" class="row_heading level0 row12" >cos_sim-Precision@10</th>
#       <td id="T_80259_row12_col0" class="data row12 col0" >0.028468</td>
#       <td id="T_80259_row12_col1" class="data row12 col1" >0.039515</td>
#       <td id="T_80259_row12_col2" class="data row12 col2" >0.069333</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row13" class="row_heading level0 row13" >cos_sim-Recall@10</th>
#       <td id="T_80259_row13_col0" class="data row13 col0" >0.284679</td>
#       <td id="T_80259_row13_col1" class="data row13 col1" >0.395151</td>
#       <td id="T_80259_row13_col2" class="data row13 col2" >0.693327</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row14" class="row_heading level0 row14" >cos_sim-MRR@10</th>
#       <td id="T_80259_row14_col0" class="data row14 col0" >0.167267</td>
#       <td id="T_80259_row14_col1" class="data row14 col1" >0.233948</td>
#       <td id="T_80259_row14_col2" class="data row14 col2" >0.489804</td>
#     </tr>
#     <tr>
#       <th id="T_80259_level0_row15" class="row_heading level0 row15" >cos_sim-NDCG@10</th>
#       <td id="T_80259_row15_col0" class="data row15 col0" >0.194887</td>
#       <td id="T_80259_row15_col1" class="data row15 col1" >0.272030</td>
#       <td id="T_80259_row15_col2" class="data row15 col2" >0.5

# %% [markdown]
# # Sanity check

# %%
from llama_index.core.storage.docstore import SimpleDocumentStore
from llama_index.core.schema import MetadataMode

val_docstore = SimpleDocumentStore.from_persist_dir(persist_dir=f"{cfg.storage_context_persist_dp}/val")

# %%
model_id = "Snowflake/snowflake-arctic-embed-m-v1.5"
base_model = SentenceTransformer(model_id)
# Out:
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# Some weights of BertModel were not initialized from the model checkpoint at Snowflake/snowflake-arctic-embed-m-v1.5 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
i = 1
sanity_node = list(val_dataset.relevant_docs.values())[i][0]
sanity_question = list(val_dataset.queries.values())[i]

# %%
print(f"""
Generated Question:
{sanity_question}

From Context:
{val_docstore.get_node(sanity_node).get_content(metadata_mode=MetadataMode.LLM)}
"""
)
# Out:
# Generated Question:
# What are some highly recommended ice cream shops known for unique flavors?
#
# From Context:
# review_stars: 5
# biz_name: Mike's Ice Cream
# biz_address: 129 2nd Ave N
# biz_city: Nashville
# biz_state: TN
# biz_categories: ['Ice Cream & Frozen Yogurt', 'Coffee & Tea', 'Restaurants', 'Sandwiches', 'Food']
#
# Some unique flavors too. Not much else to say but an amazing ice cream store that others should try to emulate.

# %%
import numpy as np
from numpy.linalg import norm

def cosine_sim(A, B):
    return np.dot(A,B)/(norm(A)*norm(B))

def calculate_sim(model, text1, text2):
    text1_embeddings = model.encode(text1)
    text2_embeddings = model.encode(text2)

    return cosine_sim(text1_embeddings, text2_embeddings)

calculate_sim(base_model, sanity_question, sanity_node)
# Out:
# 0.47004718

# %%
model_id = cfg.ft_model_dp
ft_model = SentenceTransformer(model_id)
# Out:
# You try to use a model that was created with version 2.7.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.

# %%
calculate_sim(ft_model, sanity_question, sanity_node)
# Out:
# 0.09254191

# %% [markdown]
# ## Check score between review text and review text + metadata

# %%
review_text = "Some unique flavors too. Not much else to say but an amazing ice cream store that others should try to emulate."

review_text_metadata = """
review_stars: 5
biz_name: Mike's Ice Cream
biz_address: 129 2nd Ave N
biz_city: Nashville
biz_state: TN
biz_categories: ['Ice Cream & Frozen Yogurt', 'Coffee & Tea', 'Restaurants', 'Sandwiches', 'Food']

Some unique flavors too. Not much else to say but an amazing ice cream store that others should try to emulate.
"""

# %%
calculate_sim(base_model, review_text, review_text_metadata)
# Out:
# 0.54210067

# %%
calculate_sim(ft_model, review_text, review_text_metadata)
# Out:
# 0.5803141
